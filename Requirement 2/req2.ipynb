# %% [markdown]
# # QUESTION 1

# %%
# Question 1a(i)

import pandas as pd

df = pd.read_csv('resale-flat-prices.csv')
df
# Out:
#        transaction_id    month        town         flat_type block  \
# 0                   0  2017-01  ANG MO KIO            2 ROOM   406
# 1                   1  2017-01  ANG MO KIO            3 ROOM   108
# 2                   2  2017-01  ANG MO KIO            3 ROOM   602
# 3                   3  2017-01  ANG MO KIO            3 ROOM   465
# 4                   4  2017-01  ANG MO KIO            3 ROOM   601
# ...               ...      ...         ...               ...   ...
# 77890           77890  2020-08      YISHUN         EXECUTIVE   611
# 77891           77891  2020-08      YISHUN         EXECUTIVE   643
# 77892           77892  2020-08      YISHUN         EXECUTIVE   724
# 77893           77893  2020-08      YISHUN         EXECUTIVE   877
# 77894           77894  2020-08      YISHUN  MULTI-GENERATION   666
#
#              street_name storey_range  floor_area_sqm        flat_model  \
# 0      ANG MO KIO AVE 10     10 TO 12            44.0          Improved
# ...

# %%
df = df.drop('transaction_id', axis=1)
df
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 77890  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77891  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77892  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77893  2020-08      YISHUN         EXECUTIVE   877       YISHUN ST 81
# 77894  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
# Question 1a(ii)

# Generic info of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77895 entries, 0 to 77894
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                77895 non-null  object
#  1   town                 77895 non-null  object
#  2   flat_type            77817 non-null  object
#  3   block                77895 non-null  object
#  4   street_name          77895 non-null  object
#  5   storey_range         77739 non-null  object
#  6   floor_area_sqm       77895 non-null  float64
#  7   flat_model           77895 non-null  object
#  8   lease_commence_date  77895 non-null  int64
#  9   resale_price         77895 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 5.9+ MB

# %% [markdown]
# # The dataset is made up of different data types. The columns are month, town, flat_type, block, street_name, storey_range, floor_area_sqm, flat_model, lease_commence_date, resale_price. And, there are lesser non-null values for flat_type and storey_range. These columns contain null values.

# %%
# Number of Nan values in each column
df.isnull().sum()
# Out:
# month                    0
# town                     0
# flat_type               78
# block                    0
# street_name              0
# storey_range           156
# floor_area_sqm           0
# flat_model               0
# lease_commence_date      0
# resale_price             0
# dtype: int64

# %% [markdown]
# # As mentioned earlier, both flat_type and storey_range contains null values. Hence, this is the sum of null values it contains.

# %%
# Number of rows, columns
df.shape
# Out:
# (77895, 10)

# %% [markdown]
# # The dataframe has a total of 77895 rows and 10 columns.

# %%
# Value count for each unique row
df.value_counts()
# Out:
# month    town           flat_type         block  street_name          storey_range  floor_area_sqm  flat_model         lease_commence_date  resale_price
# 2017-05  SENGKANG       EXECUTIVE         189A   RIVERVALE DR         01 TO 03      130.0           Apartment          2000                 468000.0        2
# 2017-07  CHOA CHU KANG  4 ROOM            636    CHOA CHU KANG NTH 6  04 TO 06      113.0           Premium Apartment  1998                 470000.0        2
# 2017-06  BUKIT MERAH    3 ROOM            52     HAVELOCK RD          07 TO 09      69.0            Model A            2013                 470000.0        2
# 2017-07  GEYLANG        3 ROOM            33     EUNOS CRES           10 TO 12      60.0            Model A            2007                 468000.0        2
# 2017-09  PUNGGOL        3 ROOM            623A   PUNGGOL CTRL         16 TO 18      69.0            Model A            2014                 360000.0        2
# ...

# %% [markdown]
# # The dataset has duplicated unique rows.

# %%
# Description of numeric columns in dataframe
df.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count    77895.000000         77895.000000  7.789500e+04
# mean        97.612341          1994.039155  4.386677e+05
# std         24.295162            12.783561  1.532126e+05
# min         31.000000          1966.000000  1.400000e+05
# 25%         82.000000          1984.000000  3.300000e+05
# 50%         95.000000          1994.000000  4.080000e+05
# 75%        113.000000          2003.000000  5.130000e+05
# max        249.000000          2019.000000  1.232000e+06

# %%
# Description of all columns in dataframe
df.describe(include='all')
# Out:
#           month      town flat_type  block     street_name storey_range  \
# count     77895     77895     77817  77895           77895        77739
# unique       44        26         7   2439             548           17
# top     2018-07  SENGKANG    4 ROOM      2  YISHUN RING RD     04 TO 06
# freq       2539      6168     32203    268            1203        18064
# mean        NaN       NaN       NaN    NaN             NaN          NaN
# std         NaN       NaN       NaN    NaN             NaN          NaN
# min         NaN       NaN       NaN    NaN             NaN          NaN
# 25%         NaN       NaN       NaN    NaN             NaN          NaN
# 50%         NaN       NaN       NaN    NaN             NaN          NaN
# 75%         NaN       NaN       NaN    NaN             NaN          NaN
# max         NaN       NaN       NaN    NaN             NaN          NaN
#
#         floor_area_sqm flat_model  lease_commence_date  resale_price
# ...

# %% [markdown]
# # The above 2 shows a summary of the dataset.

# %% [markdown]
# # Question 1a(iii)
#
# # 1. The average resale price is approximately $438,667. Based on the data, customers can know how much, on average, they need to pay for a resale. Likewise, resellers can also know how much, on average, they can sell their houses for.
# # 2. The most popular flat type, based on the data, is 4 room. Hence, this helps resellers to source out their biggest group of potential customers or even, help the government to construct more 4 room flats in the future.

# %%
# Question 1b(i)

removedNan_df = df.dropna()
removedNan_df = removedNan_df.reset_index()

# New shape rows = 77661, previous shape rows = 77895
removedNan_df
# Out:
#        index    month        town         flat_type block        street_name  \
# 0          0  2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          2  2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          3  2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          4  2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...      ...         ...               ...   ...                ...
# 77656  77889  2020-08      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77657  77890  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77658  77891  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77659  77892  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77660  77894  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
# ...

# %%
removedNan_df = removedNan_df.drop('index', axis=1)
removedNan_df
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 77656  2020-08      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77657  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77658  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77659  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77660  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
# NaN values dropped
removedNan_df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# dtype: int64

# %%
# Question 1b(ii)

removedNan_df.value_counts()
# Out:
# month    town           flat_type         block  street_name          storey_range  floor_area_sqm  flat_model         lease_commence_date  resale_price
# 2017-05  SENGKANG       EXECUTIVE         189A   RIVERVALE DR         01 TO 03      130.0           Apartment          2000                 468000.0        2
# 2017-07  CHOA CHU KANG  4 ROOM            636    CHOA CHU KANG NTH 6  04 TO 06      113.0           Premium Apartment  1998                 470000.0        2
# 2017-06  BUKIT MERAH    3 ROOM            52     HAVELOCK RD          07 TO 09      69.0            Model A            2013                 470000.0        2
# 2017-07  GEYLANG        3 ROOM            33     EUNOS CRES           10 TO 12      60.0            Model A            2007                 468000.0        2
# 2017-09  PUNGGOL        3 ROOM            623A   PUNGGOL CTRL         16 TO 18      69.0            Model A            2014                 360000.0        2
# ...

# %%
removedNan_df = removedNan_df.drop_duplicates()

# %%
removedNan_df.value_counts()
# Out:
# month    town        flat_type         block  street_name          storey_range  floor_area_sqm  flat_model        lease_commence_date  resale_price
# 2017-01  ANG MO KIO  2 ROOM            406    ANG MO KIO AVE 10    10 TO 12      44.0            Improved          1979                 232000.0        1
# 2019-06  SERANGOON   EXECUTIVE         520    SERANGOON NTH AVE 4  01 TO 03      156.0           Maisonette        1992                 668000.0        1
#                                        234A   SERANGOON AVE 2      13 TO 15      140.0           Apartment         1998                 979000.0        1
#                                        123    SERANGOON NTH AVE 1  10 TO 12      150.0           Maisonette        1985                 680000.0        1
#                      5 ROOM            511    SERANGOON NTH AVE 4  04 TO 06      121.0           Improved          1997                 510000.0        1
# ...

# %%
removedNan_df
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 77656  2020-08      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77657  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77658  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77659  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77660  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
removedNan_df = removedNan_df.reset_index()
removedNan_df
# Out:
#        index    month        town         flat_type block        street_name  \
# 0          0  2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          2  2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          3  2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          4  2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...      ...         ...               ...   ...                ...
# 77421  77656  2020-08      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422  77657  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423  77658  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424  77659  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425  77660  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
# ...

# %%
removedNan_df = removedNan_df.drop('index', axis=1)
removedNan_df
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 77421  2020-08      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422  2020-08      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423  2020-08      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424  2020-08      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425  2020-08      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
split_year_month = removedNan_df['month'].str.split('-')
removedNan_df['year'] = split_year_month.str.get(0).astype('int64')
removedNan_df['month'] = split_year_month.str.get(1).astype('int64')
removedNan_df = removedNan_df[['month', 'year', 'town', 'flat_type', 'block', 'street_name', 'storey_range', 
                               'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price']]

removedNan_df['end_of_lease_year'] = removedNan_df['lease_commence_date'] + 99
removedNan_df
# Out:
# <ipython-input-18-86bcd645f10a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   removedNan_df['end_of_lease_year'] = removedNan_df['lease_commence_date'] + 99
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# ...

# %%
removedNan_df['years_remaining'] = removedNan_df['end_of_lease_year'] - removedNan_df['year']
removedNan_df
# Out:
# <ipython-input-19-7f72747db353>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   removedNan_df['years_remaining'] = removedNan_df['end_of_lease_year'] - removedNan_df['year']
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# ...

# %%
# Question 1b(iii)

removedNan_df['years_remaining'].value_counts().head(10)
# Out:
# 95    4864
# 94    3933
# 66    3542
# 65    3212
# 67    3117
# 68    2542
# 79    2470
# 64    2387
# 78    2372
# 82    2359
# Name: years_remaining, dtype: int64

# %%
# Question 1c

removedNan_df.to_csv('transformed_resale_flat.csv', sep=',')

# %% [markdown]
# # QUESTION 2

# %%
# Question 2a

import pandas as pd

df = pd.read_csv('transformed_resale_flat.csv', index_col=0)
df
# Out:
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
list(df)
# Out:
# ['month',
#  'year',
#  'town',
#  'flat_type',
#  'block',
#  'street_name',
#  'storey_range',
#  'floor_area_sqm',
#  'flat_model',
#  'lease_commence_date',
#  'resale_price',
#  'end_of_lease_year',
#  'years_remaining']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77426 entries, 0 to 77425
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   month                77426 non-null  int64
#  1   year                 77426 non-null  int64
#  2   town                 77426 non-null  object
#  3   flat_type            77426 non-null  object
#  4   block                77426 non-null  object
#  5   street_name          77426 non-null  object
#  6   storey_range         77426 non-null  object
#  7   floor_area_sqm       77426 non-null  float64
#  8   flat_model           77426 non-null  object
#  9   lease_commence_date  77426 non-null  int64
#  10  resale_price         77426 non-null  float64
#  11  end_of_lease_year    77426 non-null  int64
#  12  years_remaining      77426 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 8.3+ MB

# %%
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float

Base = declarative_base()

class Resale(Base):
    __tablename__ = 'resales'
    transaction_id = Column(Integer, primary_key=True)
    month = Column(Integer)
    year = Column(Integer)
    town = Column(String)
    flat_type = Column(String)
    block = Column(String)
    street_name = Column(String)
    storey_range_min = Column(Integer)
    storey_range_max = Column(Integer)
    floor_area_sqm = Column(Float)
    flat_model = Column(String)
    lease_commence_date = Column(Integer)
    resale_price = Column(Float)
    end_of_lease_year = Column(Integer)
    years_remaining = Column(Integer)
    
    def __repr__(self):
        return "%s %s %s %s %s %s %s %s %s %s %s %s %s %s %s" %(self.transaction_id, self.month, self.year, self.town, self.flat_type,
                        self.block, self.street_name, self.storey_range_min, self.storey_range_max, self.floor_area_sqm,
                        self.flat_model, self.lease_commence_date, self.resale_price, self.end_of_lease_year,
                        self.years_remaining)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///resaleflats.db', echo=True)
Base.metadata.create_all(engine)
# Out:
# 2021-03-08 15:45:47,552 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-03-08 15:45:47,553 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,554 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-03-08 15:45:47,555 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,557 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("resales")
# 2021-03-08 15:45:47,558 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,559 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("resales")
# 2021-03-08 15:45:47,560 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,562 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE resales (
# 	transaction_id INTEGER NOT NULL,
# 	month INTEGER,
# 	year INTEGER,
# 	town VARCHAR,
# 	flat_type VARCHAR,
# 	block VARCHAR,
# 	street_name VARCHAR,
# 	storey_range_min INTEGER,
# 	storey_range_max INTEGER,
# ...

# %%
from sqlalchemy.orm import sessionmaker

engine = create_engine('sqlite:///resaleflats.db', echo=True)
Session = sessionmaker(bind=engine)
session = Session()

# %%
result = session.query(Resale)
for r in result:
    print(r)
# Out:
# 2021-03-08 15:45:47,613 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-03-08 15:45:47,614 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,615 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-03-08 15:45:47,615 INFO sqlalchemy.engine.base.Engine ()
# 2021-03-08 15:45:47,617 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# ...

# %%
def orm_add(session, row):
    transaction_id = row[0]
    month = row[1]
    year = row[2]
    town = row[3]
    flat_type = row[4]
    block = row[5]
    street_name = row[6]
    storey_range_min = int(row[7].split('TO')[0])
    storey_range_max = int(row[7].split('TO')[1])
    floor_area_sqm = row[8]
    flat_model = row[9]
    lease_commence_date = row[10]
    resale_price = row[11]
    end_of_lease_year = row[12]
    years_remaining = row[13]
    
    session.add(Resale(transaction_id=transaction_id, month=month, year=year, town=town, flat_type=flat_type, block=block,
               street_name=street_name, storey_range_min=storey_range_min, storey_range_max=storey_range_max, floor_area_sqm=floor_area_sqm, flat_model=flat_model,
               lease_commence_date=lease_commence_date, resale_price=resale_price, end_of_lease_year=end_of_lease_year, years_remaining=years_remaining))

# %%
import csv

line_count = 0

with open('transformed_resale_flat.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    header = next(csv_reader)
    
    for row in csv_reader:
        orm_add(session, row)
        line_count += 1
        
    session.commit()
# Out:
# 2021-03-08 15:45:53,378 INFO sqlalchemy.engine.base.Engine INSERT INTO resales (transaction_id, month, year, town, flat_type, block, street_name, storey_range_min, storey_range_max, floor_area_sqm, flat_model, lease_commence_date, resale_price, end_of_lease_year, years_remaining) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# ...

# %%
print(line_count)
# Out:
# 77426

# %%
# Question 2b(i)

from sqlalchemy import func

result = session.query(Resale.year, Resale.month, func.count(Resale.month)).group_by(Resale.year, Resale.month)
for r in result:
    print(f"{r[0]}-{r[1]:02d} has a total of {r[2]} transactions")
# Out:
# 2021-03-08 15:45:54,553 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2021-03-08 15:45:54,554 INFO sqlalchemy.engine.base.Engine SELECT resales.year AS resales_year, resales.month AS resales_month, count(resales.month) AS count_1
# FROM resales GROUP BY resales.year, resales.month
# 2021-03-08 15:45:54,555 INFO sqlalchemy.engine.base.Engine ()
# 2017-01 has a total of 1171 transactions
# 2017-02 has a total of 1078 transactions
# 2017-03 has a total of 1882 transactions
# 2017-04 has a total of 1818 transactions
# 2017-05 has a total of 1955 transactions
# 2017-06 has a total of 1728 transactions
# 2017-07 has a total of 1762 transactions
# 2017-08 has a total of 1938 transactions
# 2017-09 has a total of 1658 transactions
# 2017-10 has a total of 1759 transactions
# 2017-11 has a total of 1960 transactions
# 2017-12 has a total of 1568 transactions
# 2018-01 has a total of 1070 transactions
# 2018-02 has a total of 1180 transactions
# ...

# %%
# Question 2b(ii)

result = session.query(Resale.town, func.count(Resale.town)).group_by(Resale.town).order_by(func.count(Resale.town).desc())

for r in result:
    print(f"{r[0]} -> Count: {r[1]}")
# Out:
# 2021-03-08 15:45:54,609 INFO sqlalchemy.engine.base.Engine SELECT resales.town AS resales_town, count(resales.town) AS count_1
# FROM resales GROUP BY resales.town ORDER BY count(resales.town) DESC
# 2021-03-08 15:45:54,610 INFO sqlalchemy.engine.base.Engine ()
# SENGKANG -> Count: 6120
# WOODLANDS -> Count: 5870
# JURONG WEST -> Count: 5793
# YISHUN -> Count: 5435
# TAMPINES -> Count: 5012
# PUNGGOL -> Count: 4872
# BEDOK -> Count: 4176
# HOUGANG -> Count: 3676
# ANG MO KIO -> Count: 3490
# CHOA CHU KANG -> Count: 3242
# BUKIT PANJANG -> Count: 3054
# BUKIT MERAH -> Count: 3005
# BUKIT BATOK -> Count: 2864
# TOA PAYOH -> Count: 2549
# PASIR RIS -> Count: 2304
# KALLANG/WHAMPOA -> Count: 2208
# QUEENSTOWN -> Count: 2058
# SEMBAWANG -> Count: 2049
# GEYLANG -> Count: 1863
# JURONG EAST -> Count: 1734
# CLEMENTI -> Count: 1729
# SERANGOON -> Count: 1551
# BISHAN -> Count: 1482
# CENTRAL AREA -> Count: 632
# MARINE PARADE -> Count: 445
# BUKIT TIMAH -> Count: 213

# %%
# Question 2b(iii)

from sqlalchemy import and_

result = session.query(Resale.town, func.count(Resale.town))\
        .filter(and_(Resale.month >= 1, Resale.year >= 2019, Resale.storey_range_min >= 10))\
        .group_by(Resale.town)\
        .order_by(func.count(Resale.town).desc())

towns = []

for r in result:
    towns.append(r)

print("TOP 3 TOWNS")
for i in range(3):
    print(f"{towns[i][0]} - {towns[i][1]} transactions")
# Out:
# 2021-03-08 15:45:54,657 INFO sqlalchemy.engine.base.Engine SELECT resales.town AS resales_town, count(resales.town) AS count_1
# FROM resales
# WHERE resales.month >= ? AND resales.year >= ? AND resales.storey_range_min >= ? GROUP BY resales.town ORDER BY count(resales.town) DESC
# 2021-03-08 15:45:54,658 INFO sqlalchemy.engine.base.Engine (1, 2019, 10)
# TOP 3 TOWNS
# SENGKANG - 1602 transactions
# PUNGGOL - 1063 transactions
# JURONG WEST - 883 transactions

# %%
# Question 3a

import pandas as pd

df = pd.read_csv('transformed_resale_flat.csv', index_col=0)
df
# Out:
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
# What is the total number of transactions for each month?
first_column = df.groupby(['year','month']).count().iloc[:,0]
first_column
# Out:
# year  month
# 2017  1        1171
#       2        1078
#       3        1882
#       4        1818
#       5        1955
#       6        1728
#       7        1762
#       8        1938
#       9        1658
#       10       1759
#       11       1960
#       12       1568
# 2018  1        1070
#       2        1180
#       3        1876
#       4        1832
#       5        1735
#       6        1970
#       7        2523
#       8        2056
#       9        1977
#       10       1981
#       11       1860
#       12       1419
# 2019  1        1538
#       2        1300
#       3        1645
#       4        1913
#       5        2062
#       6        1880
#       7        2102
#       8        1893
#       9        1817
#       10       2200
#       11       1899
#       12       1840
# 2020  1        1904
#       2        1658
#       3        1934
#       4         421
#       5         361
#       6        2430
#       7        2452
#       8        2421
# ...

# %%
# Sort the data by town and the number of resale transactions in descending order
sorted_df = df[['town']].value_counts()
sorted_df
# Out:
# town
# SENGKANG           6120
# WOODLANDS          5870
# JURONG WEST        5793
# YISHUN             5435
# TAMPINES           5012
# PUNGGOL            4872
# BEDOK              4176
# HOUGANG            3676
# ANG MO KIO         3490
# CHOA CHU KANG      3242
# BUKIT PANJANG      3054
# BUKIT MERAH        3005
# BUKIT BATOK        2864
# TOA PAYOH          2549
# PASIR RIS          2304
# KALLANG/WHAMPOA    2208
# QUEENSTOWN         2058
# SEMBAWANG          2049
# GEYLANG            1863
# JURONG EAST        1734
# CLEMENTI           1729
# SERANGOON          1551
# BISHAN             1482
# CENTRAL AREA        632
# MARINE PARADE       445
# BUKIT TIMAH         213
# dtype: int64

# %%
# For resales transacted on and after Jan 2019 and storey range being level 10 
# and above, what are the top three towns having the greatest number of
# transactions?
sorted_df = df[(df.month >= 1) & (df.year >= 2019) & df.storey_range.str.contains(r'[123456789]\d TO \d\d')]
sorted_df
# Out:
#        month  year        town  flat_type block        street_name  \
# 41762      1  2019  ANG MO KIO     3 ROOM   418  ANG MO KIO AVE 10
# 41764      1  2019  ANG MO KIO     3 ROOM   421  ANG MO KIO AVE 10
# 41766      1  2019  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# 41767      1  2019  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10
# 41776      1  2019  ANG MO KIO     3 ROOM   121   ANG MO KIO AVE 3
# ...      ...   ...         ...        ...   ...                ...
# 77407      8  2020      YISHUN     5 ROOM   299       YISHUN ST 20
# 77411      8  2020      YISHUN     5 ROOM  334B       YISHUN ST 31
# 77412      8  2020      YISHUN     5 ROOM  336C       YISHUN ST 31
# 77415      8  2020      YISHUN     5 ROOM  505D       YISHUN ST 51
# 77419      8  2020      YISHUN  EXECUTIVE   387     YISHUN RING RD
#
#       storey_range  floor_area_sqm      flat_model  lease_commence_date  \
# 41762     13 TO 15            74.0  New Generation                 1979
# ...

# %%
towns_df = sorted_df[['town']].value_counts()
towns_df
# Out:
# town
# SENGKANG           1602
# PUNGGOL            1063
# JURONG WEST         883
# YISHUN              870
# WOODLANDS           795
# BUKIT PANJANG       784
# BUKIT MERAH         641
# BEDOK               597
# HOUGANG             590
# TAMPINES            565
# CHOA CHU KANG       559
# ANG MO KIO          527
# QUEENSTOWN          491
# TOA PAYOH           434
# SEMBAWANG           424
# KALLANG/WHAMPOA     382
# BUKIT BATOK         370
# PASIR RIS           298
# CLEMENTI            291
# JURONG EAST         281
# GEYLANG             238
# BISHAN              202
# SERANGOON           185
# CENTRAL AREA        178
# MARINE PARADE        77
# BUKIT TIMAH          24
# dtype: int64

# %%
top3towns = towns_df.head(3)
top3towns
# Out:
# town
# SENGKANG       1602
# PUNGGOL        1063
# JURONG WEST     883
# dtype: int64

# %%
# Question 3b(i)

def top3_towns_per_month(df):
    new_df = df.groupby(['year','month','town']).size().reset_index(name='count')
    level1_groupby_df = new_df.groupby(['year','month','town']).agg({'count':sum})
    level2_groupby_df = level1_groupby_df['count'].groupby(['year','month'], group_keys=False)
    top3_df = level2_groupby_df.apply(lambda x: x.sort_values(ascending=False).head(3))

    return top3_df

top3_towns_per_month(df)
# Out:
# year  month  town
# 2017  1      JURONG WEST    111
#              WOODLANDS       83
#              TAMPINES        82
#       2      YISHUN          82
#              SENGKANG        82
#                            ...
# 2020  7      SENGKANG       193
#              YISHUN         172
#       8      SENGKANG       241
#              TAMPINES       189
#              PUNGGOL        185
# Name: count, Length: 132, dtype: int64

# %%
# Question 3b(ii)

df_2020 = df[df.year==2020]
df_2020
# Out:
#        month  year        town         flat_type block        street_name  \
# 63845      1  2020  ANG MO KIO            3 ROOM   208   ANG MO KIO AVE 1
# 63846      1  2020  ANG MO KIO            3 ROOM  307C   ANG MO KIO AVE 1
# 63847      1  2020  ANG MO KIO            3 ROOM   319   ANG MO KIO AVE 1
# 63848      1  2020  ANG MO KIO            3 ROOM   216   ANG MO KIO AVE 1
# 63849      1  2020  ANG MO KIO            3 ROOM   556  ANG MO KIO AVE 10
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df_2020_towns = df_2020.groupby('town').median().reset_index()
df_2020_towns
# Out:
#                town  month  year  floor_area_sqm  lease_commence_date  \
# 0        ANG MO KIO      6  2020            82.0                 1980
# 1             BEDOK      6  2020            84.0                 1981
# 2            BISHAN      4  2020           107.0                 1989
# 3       BUKIT BATOK      6  2020            98.0                 1986
# 4       BUKIT MERAH      6  2020            88.0                 1984
# 5     BUKIT PANJANG      6  2020            93.0                 2012
# 6       BUKIT TIMAH      6  2020           104.0                 1988
# 7      CENTRAL AREA      6  2020            82.0                 1982
# 8     CHOA CHU KANG      6  2020           110.0                 1998
# 9          CLEMENTI      6  2020            80.0                 1981
# 10          GEYLANG      6  2020            74.0                 1981
# 11          HOUGANG      6  2020            99.0                 1992
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

figure, ax = plt.subplots()
ax = sns.barplot(x=df_2020_towns['resale_price'], y=df_2020_towns['town'])

# %%
# Question 3b(iii)

df_2020
# Out:
#        month  year        town         flat_type block        street_name  \
# 63845      1  2020  ANG MO KIO            3 ROOM   208   ANG MO KIO AVE 1
# 63846      1  2020  ANG MO KIO            3 ROOM  307C   ANG MO KIO AVE 1
# 63847      1  2020  ANG MO KIO            3 ROOM   319   ANG MO KIO AVE 1
# 63848      1  2020  ANG MO KIO            3 ROOM   216   ANG MO KIO AVE 1
# 63849      1  2020  ANG MO KIO            3 ROOM   556  ANG MO KIO AVE 10
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df_2020[['town']].value_counts()
# Out:
# town
# SENGKANG           1192
# YISHUN             1127
# TAMPINES            954
# WOODLANDS           911
# PUNGGOL             893
# JURONG WEST         875
# BEDOK               768
# HOUGANG             717
# BUKIT PANJANG       698
# ANG MO KIO          598
# CHOA CHU KANG       593
# PASIR RIS           482
# BUKIT MERAH         440
# BUKIT BATOK         422
# TOA PAYOH           378
# QUEENSTOWN          355
# CLEMENTI            331
# GEYLANG             318
# SEMBAWANG           303
# KALLANG/WHAMPOA     301
# JURONG EAST         296
# SERANGOON           230
# BISHAN              221
# CENTRAL AREA         90
# MARINE PARADE        63
# BUKIT TIMAH          25
# dtype: int64

# %%
df_2020_SK = df_2020[df_2020.town=='SENGKANG']
df_2020_SK
# Out:
#        month  year      town  flat_type block        street_name storey_range  \
# 65050      1  2020  SENGKANG     2 ROOM  302B    ANCHORVALE LINK     13 TO 15
# 65051      1  2020  SENGKANG     2 ROOM  302B    ANCHORVALE LINK     13 TO 15
# 65052      1  2020  SENGKANG     2 ROOM  453A        FERNVALE RD     07 TO 09
# 65053      1  2020  SENGKANG     2 ROOM  448B  SENGKANG WEST WAY     22 TO 24
# 65054      1  2020  SENGKANG     2 ROOM  450C  SENGKANG WEST WAY     16 TO 18
# ...      ...   ...       ...        ...   ...                ...          ...
# 76811      8  2020  SENGKANG  EXECUTIVE  203D     COMPASSVALE RD     01 TO 03
# 76812      8  2020  SENGKANG  EXECUTIVE  291C     COMPASSVALE ST     04 TO 06
# 76813      8  2020  SENGKANG  EXECUTIVE  117B       RIVERVALE DR     01 TO 03
# 76814      8  2020  SENGKANG  EXECUTIVE  202B   SENGKANG EAST RD     07 TO 09
# 76815      8  2020  SENGKANG  EXECUTIVE  122C  SENGKANG EAST WAY     16 TO 18
#
# ...

# %%
df_2020_SK_flat_type = df_2020_SK.groupby(['flat_type', 'month']).median().reset_index()
df_2020_SK_flat_type
# Out:
#     flat_type  month    year  floor_area_sqm  lease_commence_date  \
# 0      2 ROOM      1  2020.0            46.0               2014.0
# 1      2 ROOM      2  2020.0            47.0               2013.0
# 2      2 ROOM      3  2020.0            46.5               2014.0
# 3      2 ROOM      4  2020.0            47.0               2015.0
# 4      2 ROOM      6  2020.0            47.0               2015.0
# 5      2 ROOM      7  2020.0            47.0               2012.0
# 6      2 ROOM      8  2020.0            47.0               2012.0
# 7      3 ROOM      1  2020.0            67.0               2014.5
# 8      3 ROOM      2  2020.0            67.0               2015.0
# 9      3 ROOM      3  2020.0            67.5               2014.0
# 10     3 ROOM      4  2020.0            67.0               2015.0
# 11     3 ROOM      5  2020.0            67.0               2015.0
# 12     3 ROOM      6  2020.0            67.0               2015.0
# ...

# %%
figure, ax = plt.subplots()
ax = sns.barplot(x=df_2020_SK_flat_type['flat_type'], y=df_2020_SK_flat_type['resale_price'], hue=df_2020_SK_flat_type['month'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
plt.tight_layout()

# %%
# Question 3b(iv)

df
# Out:
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
split_storey_range =  df['storey_range'].str.split('TO')
df_with_min_storey = df.copy()
df_with_min_storey['min_storey'] = split_storey_range.str.get(0).astype('int64')
df_with_min_storey
# Out:
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df_with_min_storey = df_with_min_storey.sort_values(by=['min_storey'])
df_with_min_storey
# Out:
#        month  year          town         flat_type block          street_name  \
# 77425      8  2020        YISHUN  MULTI-GENERATION   666         YISHUN AVE 4
# 48436      5  2019   BUKIT BATOK            5 ROOM   348       BT BATOK ST 34
# 48425      5  2019   BUKIT BATOK            4 ROOM   118  BT BATOK WEST AVE 6
# 14719      9  2017     TOA PAYOH            3 ROOM   102   POTONG PASIR AVE 1
# 48413      5  2019   BUKIT BATOK            4 ROOM   341       BT BATOK ST 34
# ...      ...   ...           ...               ...   ...                  ...
# 2691       3  2017  CENTRAL AREA            4 ROOM    1E        CANTONMENT RD
# 52592      7  2019  CENTRAL AREA            4 ROOM    1F        CANTONMENT RD
# 21607      2  2018  CENTRAL AREA            4 ROOM    1E        CANTONMENT RD
# 305        1  2017  CENTRAL AREA            5 ROOM    1B        CANTONMENT RD
# 73129      7  2020  CENTRAL AREA            4 ROOM    1D        CANTONMENT RD
#
# ...

# %%
figure, ax = plt.subplots()
ax = sns.barplot(x=df_with_min_storey['resale_price'], y=df_with_min_storey['storey_range'])

# %% [markdown]
# # Yes, there is a correlation between the storey range and resale price. The higher the storey range, the higher the resale price.

# %%
# Question 3b(v)

df
# Out:
#        month  year        town         flat_type block        street_name  \
# 0          1  2017  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1          1  2017  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2          1  2017  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3          1  2017  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4          1  2017  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...      ...   ...         ...               ...   ...                ...
# 77421      8  2020      YISHUN         EXECUTIVE   258       YISHUN ST 22
# 77422      8  2020      YISHUN         EXECUTIVE   611       YISHUN ST 61
# 77423      8  2020      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 77424      8  2020      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 77425      8  2020      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
figure, ax = plt.subplots()
ax = sns.violinplot(x=df['years_remaining'], y=df['resale_price'])

# %% [markdown]
# # Yes, there is a correlation between the remaining lease in years and resale price. The higher the remaining lease in years, the higher the resale price.

# %%
df_yishun = df[df.town=='YISHUN']
df_yishun
# Out:
#        month  year    town         flat_type block     street_name  \
# 1101       1  2017  YISHUN            2 ROOM   451  YISHUN RING RD
# 1102       1  2017  YISHUN            3 ROOM   773    YISHUN AVE 3
# 1103       1  2017  YISHUN            3 ROOM   774    YISHUN AVE 3
# 1104       1  2017  YISHUN            3 ROOM   618  YISHUN RING RD
# 1105       1  2017  YISHUN            3 ROOM   126    YISHUN ST 11
# ...      ...   ...     ...               ...   ...             ...
# 77421      8  2020  YISHUN         EXECUTIVE   258    YISHUN ST 22
# 77422      8  2020  YISHUN         EXECUTIVE   611    YISHUN ST 61
# 77423      8  2020  YISHUN         EXECUTIVE   643    YISHUN ST 61
# 77424      8  2020  YISHUN         EXECUTIVE   724    YISHUN ST 71
# 77425      8  2020  YISHUN  MULTI-GENERATION   666    YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# 1101      04 TO 06            47.0           Model A                 2012
# ...

# %%
df_yishun_flat_type = df_yishun.groupby(['year','flat_type']).median().reset_index()
df_yishun_flat_type
# Out:
#     year         flat_type  month  floor_area_sqm  lease_commence_date  \
# 0   2017            2 ROOM    7.5            48.0               2013.0
# 1   2017            3 ROOM    7.0            67.0               1985.0
# 2   2017            4 ROOM    7.0            93.0               1988.0
# 3   2017            5 ROOM    6.0           122.0               1987.0
# 4   2017         EXECUTIVE    6.0           146.0               1988.0
# 5   2017  MULTI-GENERATION   10.0           165.0               1987.0
# 6   2018            2 ROOM    5.0            48.0               2013.0
# 7   2018            3 ROOM    7.0            67.0               1985.0
# 8   2018            4 ROOM    7.0            93.0               1988.0
# 9   2018            5 ROOM    8.0           121.5               1987.0
# 10  2018         EXECUTIVE    5.0           146.0               1988.0
# 11  2018  MULTI-GENERATION    9.0           164.0               1987.0
# ...

# %%
figure, ax = plt.subplots()
ax = sns.barplot(x=df_yishun_flat_type['year'], y=df_yishun_flat_type['resale_price'], hue=df_yishun_flat_type['flat_type'])
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
plt.tight_layout()
